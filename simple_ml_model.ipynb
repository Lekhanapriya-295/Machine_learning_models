# %% [markdown]
# <a href="https://colab.research.google.com/github/Lekhanapriya-295/Machine_learning_models/blob/main/simple_ml_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
def Ml_pairs(n):
    X_train = np.array([[0], [1], [2]])
    y_train = np.array([n-0, n-1, n-2])

    model = LinearRegression()
    model.fit(X_train, y_train)

    print(f"Output for {n}:")

    for x in range(n + 1):
        prediction = model.predict([[x]])
        y = int(np.round(prediction[0]))
        print(f"{x} + {y}")

# %%
user_input = 58
Ml_pairs(user_input)
# Out:
# Output for 58:
# 0 + 58
# 1 + 57
# 2 + 56
# 3 + 55
# 4 + 54
# 5 + 53
# 6 + 52
# 7 + 51
# 8 + 50
# 9 + 49
# 10 + 48
# 11 + 47
# 12 + 46
# 13 + 45
# 14 + 44
# 15 + 43
# 16 + 42
# 17 + 41
# 18 + 40
# 19 + 39
# 20 + 38
# 21 + 37
# 22 + 36
# 23 + 35
# 24 + 34
# 25 + 33
# 26 + 32
# 27 + 31
# 28 + 30
# 29 + 29
# 30 + 28
# 31 + 27
# 32 + 26
# 33 + 25
# 34 + 24
# 35 + 23
# 36 + 22
# 37 + 21
# 38 + 20
# 39 + 19
# 40 + 18
# 41 + 17
# 42 + 16
# 43 + 15
# 44 + 14
# 45 + 13
# 46 + 12
# 47 + 11
# 48 + 10
# 49 + 9
# 50 + 8
# 51 + 7
# 52 + 6
# 53 + 5
# 54 + 4
# 55 + 3
# 56 + 2
# 57 + 1
# 58 + 0
